# %%
# General Libraries
import os
import math
import json
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Google Colab
from google.colab import drive
import gdown

# Scikit-learn (Data Processing & ML)
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import mean_absolute_error

# TensorFlow & Keras (Deep Learning)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.models import load_model
import gc
import tensorflow.keras.backend as K

# %%
# Mount Google Drive
# Define Google Drive Folder ID
FOLDER_ID = "1VM2BEzEf6DWlQJjtFA5V4z5oq1DteCGd"

# Define Local Folder Path
local_data_folder = "/content/Building_59_clean_data/"

# Download the Dataset
if not os.path.exists(local_data_folder):  # Avoid downloading multiple times
    os.makedirs(local_data_folder, exist_ok=True)
    gdown.download_folder(f"https://drive.google.com/drive/folders/{FOLDER_ID}", output=local_data_folder, quiet=False, use_cookies=False)

# Load CSV Files Dynamically
csv_files = glob.glob(os.path.join(local_data_folder, "**", "*.csv"), recursive = True)

# Print Found Files
print(f" Found {len(csv_files)} CSV files in the dataset!")
# Out:
# Retrieving folder contents
# Retrieving folder 1lE1_W-Q1AM-C9armgXluf6o02UlPEART Building_59_clean_data
# Processing file 1PppEv6dsCvvqslRmgU_tA_RXrvF2cPfl ashp_cw.csv
# Processing file 1nJS5GA0NsyoI4FTFI7uY-JaqlCXHB3So ashp_hw.csv
# Processing file 1k3kPGBZz-4sH1H6tmu76nlYprZAZqMif ashp_meter.csv
# Processing file 1pfyD3P0TW6HKosOPhwkk59Y3lE0FlAMU ele.csv
# Processing file 1rB7cz0fbuiC_PF34GG-1MKAn_s22JJgi hp_hws_temp.csv
# Processing file 1KacWR2exzpd_qlYmPA-xgJKlpKzuJ1r2 occ.csv
# Processing file 14rrxFDmyDiJR5KAw98-F6h_Xr73ElA6u rtu_econ_sp.csv
# Processing file 126OBRZJs8pcSmmsXg7BQFiAOagFauxwq rtu_fan_spd.csv
# Processing file 110ijIyeRkV3Zn22YjzG0duYYYaJZUiJm rtu_ma_t.csv
# Processing file 1SDzXOYCmM2HY8Em7APRIk8nNCXgXiAB2 rtu_oa_damper.csv
# Processing file 1r0q-GfdfsEQe7wq2Jxly4NoiUzwvkGZO rtu_oa_fr.csv
# Processing file 1SUtGC42hFIoVTgr62iGx74f4jVrijMqW rtu_oa_t.csv
# Processing file 1yG3DGWb4fUxJtdcvZZRmTgHSRfBhH8rs rtu_plenum_p.csv
# Processing file 1AAUrUJ8K-4b1PbzWQ5WTuMvrpEsEtewY rtu_ra_t.csv
# Processing file 1lQWMYGPU8qdwKS0XjOtpYo_Cz3BKNNQ6 rtu_sa_fr.csv
# Processing file 1qtHd4i6u22WMt16yH9OSKXUvNGzqnxoF rtu_sa_p_sp.csv
# Processing file 1Vmqun2VknhvFnTcKYJFkXmByOOUWgmyG rtu_sa_t_sp.csv
# Processing file 1hsuYo9EWRQiTXdr3qcLlduiKMdi0gACr rtu_sa_t.csv
# Processing file 1V6ZWk33ffAEArsoH4QZBPjkmKPOMWdJE site_weather.csv
# Processing file 1A1DERja-YOZccTUyI1ictrheJvlL2jI_ uft_fan_spd.csv
# Processing file 14YA4AKucTNDdK4-6DP7vKGnCYufZ1cjf uft_hw_valve.csv
# Processing file 183Kz3ZthNWKLBQfT3USPRr3ExYl9Qgf3 wifi.csv
# Processing file 121Iwo5_A_TII10C8XsHIpO2xZJHdGNn7 zone_co2.csv
# Processing file 1dxv8ZVThnzLndEmA9FGxmOq3JiNt4-gT zone_temp_exterior.csv
# Processing file 1MO1sH9-82GNW-9-YCwhD773I_O-uR-AI zone_temp_interior.csv
# Processing file 1dF4fijRAdJcG5YwNkZdOq_yRjDWuNSin zone_temp_sp_c.csv
# Processing file 1Ok_JqBCt26HIPxgkOl8A2rYQks2N5Bqu zone_temp_sp_h.csv
# Processing file 1oHE-fNkSkmEvdoGvKSUpK0mG1pmspfuZ Bldg59_w_occ Brick model.ttl
# Processing file 1XMUAWTo7bgUUy9IwjcDFL-jPfCdNhhFG Bldg59_w_occ metadata of dataset.json
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1PppEv6dsCvvqslRmgU_tA_RXrvF2cPfl
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_cw.csv
# 100%|██████████| 1.73M/1.73M [00:00<00:00, 122MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nJS5GA0NsyoI4FTFI7uY-JaqlCXHB3So
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_hw.csv
# 100%|██████████| 5.55M/5.55M [00:00<00:00, 46.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1k3kPGBZz-4sH1H6tmu76nlYprZAZqMif
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_meter.csv
# 100%|██████████| 1.50M/1.50M [00:00<00:00, 149MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1pfyD3P0TW6HKosOPhwkk59Y3lE0FlAMU
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/ele.csv
# 100%|██████████| 6.16M/6.16M [00:00<00:00, 14.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rB7cz0fbuiC_PF34GG-1MKAn_s22JJgi
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/hp_hws_temp.csv
# 100%|██████████| 23.2M/23.2M [00:00<00:00, 57.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KacWR2exzpd_qlYmPA-xgJKlpKzuJ1r2
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/occ.csv
# 100%|██████████| 11.7M/11.7M [00:00<00:00, 152MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14rrxFDmyDiJR5KAw98-F6h_Xr73ElA6u
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_econ_sp.csv
# 100%|██████████| 41.2M/41.2M [00:00<00:00, 55.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=126OBRZJs8pcSmmsXg7BQFiAOagFauxwq
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_fan_spd.csv
# 100%|██████████| 86.6M/86.6M [00:00<00:00, 123MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=110ijIyeRkV3Zn22YjzG0duYYYaJZUiJm
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_ma_t.csv
# 100%|██████████| 50.0M/50.0M [00:00<00:00, 73.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SDzXOYCmM2HY8Em7APRIk8nNCXgXiAB2
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_damper.csv
# 100%|██████████| 47.4M/47.4M [00:00<00:00, 112MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1r0q-GfdfsEQe7wq2Jxly4NoiUzwvkGZO
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_fr.csv
# 100%|██████████| 82.3M/82.3M [00:00<00:00, 84.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SUtGC42hFIoVTgr62iGx74f4jVrijMqW
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_t.csv
# 100%|██████████| 50.0M/50.0M [00:00<00:00, 101MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1yG3DGWb4fUxJtdcvZZRmTgHSRfBhH8rs
# From (redirected): https://drive.google.com/uc?id=1yG3DGWb4fUxJtdcvZZRmTgHSRfBhH8rs&confirm=t&uuid=d47059b5-9c9a-4685-8bd6-511fee084631
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_plenum_p.csv
# 100%|██████████| 138M/138M [00:01<00:00, 73.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1AAUrUJ8K-4b1PbzWQ5WTuMvrpEsEtewY
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_ra_t.csv
# 100%|██████████| 50.0M/50.0M [00:00<00:00, 135MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lQWMYGPU8qdwKS0XjOtpYo_Cz3BKNNQ6
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_fr.csv
# 100%|██████████| 96.6M/96.6M [00:00<00:00, 126MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1qtHd4i6u22WMt16yH9OSKXUvNGzqnxoF
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_p_sp.csv
# 100%|██████████| 57.4M/57.4M [00:00<00:00, 113MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Vmqun2VknhvFnTcKYJFkXmByOOUWgmyG
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_t_sp.csv
# 100%|██████████| 78.0M/78.0M [00:00<00:00, 145MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hsuYo9EWRQiTXdr3qcLlduiKMdi0gACr
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_t.csv
# 100%|██████████| 59.2M/59.2M [00:00<00:00, 113MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1V6ZWk33ffAEArsoH4QZBPjkmKPOMWdJE
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/site_weather.csv
# 100%|██████████| 5.32M/5.32M [00:00<00:00, 38.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1A1DERja-YOZccTUyI1ictrheJvlL2jI_
# From (redirected): https://drive.google.com/uc?id=1A1DERja-YOZccTUyI1ictrheJvlL2jI_&confirm=t&uuid=a0e75a0a-75b1-4ed2-9984-63b97c791d86
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/uft_fan_spd.csv
# 100%|██████████| 400M/400M [00:04<00:00, 91.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14YA4AKucTNDdK4-6DP7vKGnCYufZ1cjf
# From (redirected): https://drive.google.com/uc?id=14YA4AKucTNDdK4-6DP7vKGnCYufZ1cjf&confirm=t&uuid=c04d8862-8fba-4569-b417-7eb3767f74ae
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/uft_hw_valve.csv
# 100%|██████████| 462M/462M [00:03<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=183Kz3ZthNWKLBQfT3USPRr3ExYl9Qgf3
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/wifi.csv
# 100%|██████████| 2.74M/2.74M [00:00<00:00, 15.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=121Iwo5_A_TII10C8XsHIpO2xZJHdGNn7
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_co2.csv
# 100%|██████████| 39.0M/39.0M [00:00<00:00, 87.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1dxv8ZVThnzLndEmA9FGxmOq3JiNt4-gT
# From (redirected): https://drive.google.com/uc?id=1dxv8ZVThnzLndEmA9FGxmOq3JiNt4-gT&confirm=t&uuid=44abcb99-10c3-4eaa-acf5-9698e060650d
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_exterior.csv
# 100%|██████████| 421M/421M [00:03<00:00, 107MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MO1sH9-82GNW-9-YCwhD773I_O-uR-AI
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_interior.csv
# 100%|██████████| 32.6M/32.6M [00:00<00:00, 65.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dF4fijRAdJcG5YwNkZdOq_yRjDWuNSin
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_sp_c.csv
# 100%|██████████| 40.7M/40.7M [00:00<00:00, 80.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ok_JqBCt26HIPxgkOl8A2rYQks2N5Bqu
# To: /content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_sp_h.csv
# 100%|██████████| 39.6M/39.6M [00:00<00:00, 95.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oHE-fNkSkmEvdoGvKSUpK0mG1pmspfuZ
# To: /content/Building_59_clean_data/Building_59/Bldg59_w_occ Brick model.ttl
# 100%|██████████| 38.8k/38.8k [00:00<00:00, 17.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XMUAWTo7bgUUy9IwjcDFL-jPfCdNhhFG
# To: /content/Building_59_clean_data/Building_59/Bldg59_w_occ metadata of dataset.json
# 100%|██████████| 35.3k/35.3k [00:00<00:00, 39.9MB/s]
#  Found 27 CSV files in the dataset!
# Download completed

# %%
# Check all .csv files
print("🔍 Found CSV files:", csv_files)

all_columns = set()
for file in csv_files:
    df = pd.read_csv(file, nrows=5)  # Load only first 5 rows to check columns
    all_columns.update(df.columns)   # Add to set to avoid duplicates

# Sort and display all columns
all_columns = sorted(all_columns)
print(" All Column Names in Dataset:")
print(all_columns)

# for file in csv_files:
#     print(f"📂 File: {os.path.basename(file)}")  # Print filename
#     df = pd.read_csv(file)
#     display(df.head(5))  # Display the first 5 rows
#     print("\n" + "="*80 + "\n")  # Separator for readability
# Out:
# 🔍 Found CSV files: ['/content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_meter.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_hw.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_interior.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_exterior.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_econ_sp.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/uft_fan_spd.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_fr.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_plenum_p.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_t_sp.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_fr.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/site_weather.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_sp_h.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_ra_t.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/occ.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/ashp_cw.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_t.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/hp_hws_temp.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/uft_hw_valve.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_fan_spd.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_ma_t.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_temp_sp_c.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_oa_damper.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/wifi.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_p_sp.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/rtu_sa_t.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/ele.csv', '/content/Building_59_clean_data/Building_59/Building_59_clean_data/zone_co2.csv']
#  All Column Names in Dataset:
# ['Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 6', 'air_temp_set_1', 'air_temp_set_2', 'aru_001_cwr_temp', 'aru_001_cws_fr_gpm', 'aru_001_cws_temp', 'aru_001_hwr_temp', 'aru_001_hws_fr_gpm', 'aru_001_hws_temp', 'aru_001_power_mbtuph', 'cerc_templogger_1', 'cerc_templogger_10', 'cerc_templogger_11', 'cerc_templogger_12', 'cerc_templogger_13', 'cerc_templogger_14', 'cerc_templogger_15', 'cerc_templogger_16', 'cerc_templogger_2', 'cerc_templogger_3', 'cerc_templogger_4', 'cerc_templogger_5', 'cerc_templogger_6', 'cerc_templogger_7', 'cerc_templogger_8', 'cerc_templogger_9', 'date', 'dew_point_temperature_set_1d', 'hp_hws_temp', 'hvac_N', 'hvac_S', 'lig_S', 'mels_N', 'mels_S', 'occ_fourth_south', 'occ_third_south', 'relative_humidity_set_1', 'rtu_001_econ_stpt_tn', 'rtu_001_fltrd_gnd_lvl_plenum_press_tn', 'rtu_001_fltrd_lvl2_plenum_press_tn', 'rtu_001_fltrd_sa_flow_tn', 'rtu_001_ma_temp', 'rtu_001_oa_flow_tn', 'rtu_001_oa_temp', 'rtu_001_oadmpr_pct', 'rtu_001_pa_static_stpt_tn', 'rtu_001_ra_temp', 'rtu_001_rf_vfd_spd_fbk_tn', 'rtu_001_sa_temp', 'rtu_001_sat_sp_tn', 'rtu_001_sf_vfd_spd_fbk_tn', 'rtu_002_econ_stpt_tn', 'rtu_002_fltrd_gnd_lvl_plenum_press_tn', 'rtu_002_fltrd_lvl2_plenum_press_tn', 'rtu_002_fltrd_sa_flow_tn', 'rtu_002_ma_temp', 'rtu_002_oa_flow_tn', 'rtu_002_oa_temp', 'rtu_002_oadmpr_pct', 'rtu_002_pa_static_stpt_tn', 'rtu_002_ra_temp', 'rtu_002_rf_vfd_spd_fbk_tn', 'rtu_002_sa_temp', 'rtu_002_sat_sp_tn', 'rtu_002_sf_vfd_spd_fbk_tn', 'rtu_003_econ_stpt_tn', 'rtu_003_fltrd_gnd_lvl_plenum_press_tn', 'rtu_003_fltrd_lvl2_plenum_press_tn', 'rtu_003_fltrd_sa_flow_tn', 'rtu_003_ma_temp', 'rtu_003_oa_flow_tn', 'rtu_003_oa_temp', 'rtu_003_oadmpr_pct', 'rtu_003_pa_static_stpt_tn', 'rtu_003_ra_temp', 'rtu_003_rf_vfd_spd_fbk_tn', 'rtu_003_sa_temp', 'rtu_003_sat_sp_tn', 'rtu_003_sf_vfd_spd_fbk_tn', 'rtu_004_econ_stpt_tn', 'rtu_004_fltrd_gnd_lvl_plenum_press_tn', 'rtu_004_fltrd_lvl2_plenum_press_tn', 'rtu_004_fltrd_sa_flow_tn', 'rtu_004_ma_temp', 'rtu_004_oa_flow_tn', 'rtu_004_oa_temp', 'rtu_004_oadmpr_pct', 'rtu_004_pa_static_stpt_tn', 'rtu_004_ra_temp', 'rtu_004_rf_vfd_spd_fbk_tn', 'rtu_004_sa_temp', 'rtu_004_sat_sp_tn', 'rtu_004_sf_vfd_spd_fbk_tn', 'solar_radiation_set_1', 'wifi_first_south', 'wifi_fourth_south', 'wifi_second_south', 'wifi_third_south', 'zone_016_cooling_sp', 'zone_016_fan_spd', 'zone_016_heating_sp', 'zone_016_hw_valve', 'zone_016_temp', 'zone_017_cooling_sp', 'zone_017_fan_spd', 'zone_017_heating_sp', 'zone_017_hw_valve', 'zone_017_temp', 'zone_018_cooling_sp', 'zone_018_fan_spd', 'zone_018_heating_sp', 'zone_018_hw_valve', 'zone_018_temp', 'zone_019_cooling_sp', 'zone_019_fan_spd', 'zone_019_heating_sp', 'zone_019_temp', 'zone_021_cooling_sp', 'zone_021_fan_spd', 'zone_021_heating_sp', 'zone_021_hw_valve', 'zone_021_temp', 'zone_022_co2', 'zone_022_fan_spd', 'zone_022_hw_valve', 'zone_022_temp', 'zone_023_cooling_sp', 'zone_023_fan_spd', 'zone_023_heating_sp', 'zone_023_hw_valve', 'zone_023_temp', 'zone_024_cooling_sp', 'zone_024_fan_spd', 'zone_024_heating_sp', 'zone_024_hw_valve', 'zone_024_temp', 'zone_025_cooling_sp', 'zone_025_fan_spd', 'zone_025_heating_sp', 'zone_025_hw_valve', 'zone_025_temp', 'zone_026_cooling_sp', 'zone_026_fan_spd', 'zone_026_heating_sp', 'zone_026_hw_valve', 'zone_026_temp', 'zone_027_cooling_sp', 'zone_027_fan_spd', 'zone_027_heating_sp', 'zone_027_hw_valve', 'zone_027_temp', 'zone_028_co2', 'zone_028_fan_spd', 'zone_028_hw_valve', 'zone_028_temp', 'zone_030_cooling_sp', 'zone_030_fan_spd', 'zone_030_heating_sp', 'zone_030_temp', 'zone_032_cooling_sp', 'zone_032_fan_spd', 'zone_032_heating_sp', 'zone_032_temp', 'zone_033_co2', 'zone_033_fan_spd', 'zone_033_temp', 'zone_035_cooling_sp', 'zone_035_fan_spd', 'zone_035_heating_sp', 'zone_035_hw_valve', 'zone_035_temp', 'zone_036_cooling_sp', 'zone_036_fan_spd', 'zone_036_heating_sp', 'zone_036_hw_valve', 'zone_036_temp', ' ...

# %%
# Merge all essential .csv files and keep only data from the year 2020

essential_sensor_files = [
    "ele.csv",  # Electrical meter data
    "rtu_sa_t.csv",  # HVAC Supply Air temperature
    "zone_temp_interior.csv",  # Interior zone temperatures
    "zone_temp_exterior.csv",  # Exterior temperature
    "rtu_fan_spd.csv",  # Fan speeds for HVAC units
    "ashp_meter.csv",  # Air source heat pump energy use
    "ashp_cw.csv", "ashp_hw.csv",  # Chilled water & Hot water from ASHP
]

# Filter only the necessary files
filtered_files = [f for f in csv_files if os.path.basename(f) in essential_sensor_files]
print(f"🔍 Found {len(filtered_files)} essential sensor CSV files!")

# Create a full timestamp range (2020, 5-minute intervals)
full_time_index = pd.date_range(start="2020-01-01 00:00:00", end="2020-12-31 23:55:00", freq="5min")
full_time_df = pd.DataFrame({"date": full_time_index})

# Load files, fix timestamps, and align to full time range
dfs = []
for file in filtered_files:
    df = pd.read_csv(file)

    # Print shape to check if files are loading correctly
    print(f"📂 Loaded {os.path.basename(file)} with shape {df.shape}")

    # Ensure date column is datetime
    df["date"] = pd.to_datetime(df["date"], errors="coerce")

    # Drop rows where date couldn't be parsed
    df = df.dropna(subset=["date"])

    # Sort and reset index
    df = df.sort_values("date").reset_index(drop=True)

    # Merge with full timestamp range using outer join
    df = full_time_df.merge(df, on="date", how="left")

    # Store cleaned dataset
    dfs.append(df)

# Merge all datasets into one using an outer join
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on="date", how="outer", suffixes=("", "_dup"))

# Drop any duplicate columns that may have been added
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]

# Display final shape & first rows
print("Final merged dataset shape:", merged_df.shape)
display(merged_df.head(20))
# Out:
# 🔍 Found 8 essential sensor CSV files!
# 📂 Loaded ashp_meter.csv with shape (43978, 2)
# 📂 Loaded ashp_hw.csv with shape (124487, 4)
# 📂 Loaded zone_temp_interior.csv with shape (149696, 17)
# 📂 Loaded zone_temp_exterior.csv with shape (1511904, 52)
# 📂 Loaded ashp_cw.csv with shape (43979, 4)
# 📂 Loaded rtu_fan_spd.csv with shape (1382051, 9)
# 📂 Loaded rtu_sa_t.csv with shape (1407323, 5)
# 📂 Loaded ele.csv with shape (103048, 7)
# Final merged dataset shape: (112368, 93)
#                   date  aru_001_power_mbtuph  aru_001_hwr_temp  \
# 0  2020-01-01 00:00:00                   NaN            121.55
# 1  2020-01-01 00:05:00                   NaN            120.95
# 2  2020-01-01 00:10:00                   NaN            117.23
# 3  2020-01-01 00:15:00                   NaN            120.61
# 4  2020-01-01 00:20:00                   NaN            122.66
# 5  2020-01-01 00:25:00                   NaN            118.29
# 6  2020-01-01 00:30:00                   NaN            120.17
# 7  2020-01-01 00:35:00                   NaN            122.48
# 8  2020-01-01 00:40:00                   NaN            118.76
# 9  2020-01-01 00:45:00                   NaN            120.01
# 10 2020-01-01 00:50:00                   NaN            122.40
# 11 2020-01-01 00:55:00                   NaN            119.41
# 12 2020-01-01 01:00:00                   NaN            119.85
# 13 2020-01-01 01:05:00                   NaN            122.46
# 14 2020-01-01 01:10:00                   NaN            119.12
# 15 2020-01-01 01:15:00                   NaN            119.79
# 16 2020-01-01 01:20:00                   NaN            122.37
# 17 2020-01-01 01:25:00                   NaN            119.72
# 18 2020-01-01 01:30:00                   NaN            119.33
# 19 2020-01-01 01:35:00                   NaN            122.02
#
#     aru_001_hws_fr_gpm  aru_001_hws_temp  cerc_templogger_1  \
# 0                62.36            126.27             22.687
# 1                62.26            121.87                NaN
# 2                62.26            121.76             22.750
# 3                62.25            125.12                NaN
# 4                62.25            124.05             22.750
# 5                62.15            118.41                NaN
# 6                62.25            124.60             22.875
# 7                62.03            125.07                NaN
# 8                62.28            118.90             22.812
# 9                62.25            124.35                NaN
# 10               62.36            127.13             22.625
# 11               62.15            119.72                NaN
# 12               62.47            124.02             22.687
# 13               62.12            126.91                NaN
# 14               62.14            119.45             22.625
# 15               62.36            124.29                NaN
# 16               62.36            126.91             22.750
# 17               62.14            120.22                NaN
# 18               62.36            123.49             22.937
# 19               62.36            126.63                NaN
#
#     cerc_templogger_10  cerc_templogger_11  cerc_templogger_12  \
# 0             0.000000              24.000              23.937
# 1                  NaN                 NaN                 NaN
# 2            24.029814              24.312              24.000
# 3                  NaN                 NaN                 NaN
# 4            24.017178              24.375              23.875
# 5                  NaN                 NaN                 NaN
# 6            23.903450              24.062              23.750
# 7                  NaN                 NaN                 NaN
# 8            24.009684              24.125              23.937
# 9                  NaN                 NaN                 NaN
# 10           23.825978              23.875              23.812
# 11                 NaN                 NaN                 NaN
# 12           24.011116              24.187              23.875
# 13                 NaN                 NaN                 NaN
# 14           23.989723              24.437              24.000
# 15                 NaN                 NaN                 NaN
# 16           24.063019              24.437              24.062
# 17                 NaN                 NaN                 NaN
# 18           24.013495              24.437              24.062
# 19                 NaN                 NaN                 NaN
#
#     cerc_templogger_13  ...  rtu_001_sa_temp  rtu_002_sa_temp  \
# 0               23.937  ...             62.5             67.7
# 1                  NaN  ...             65.2             67.4
# 2               24.312  ...             64.6             68.7
# 3                  NaN  ...             63.1             68.3
# 4               23.875  ...             63.3             67.1
# 5                  NaN  ...             64.7             67.2
# 6               23.937  ...             61.9             67.9
# 7                  NaN  ...             64.9             68.6
# 8               23.937  ...             64.9             68.8
# 9                  NaN  ...             62.7             69.1
# 10              23.937  ...             64.5             68.9
# 11                 NaN  ...             64.7             67.6
# 12              24.000  ...             64.7             66.6
# 13                 NaN  ...             69.9             67.0
# 14              23.937  ...             71.1             68.0
# 15                 NaN  ...             71.4             68.5
# 16              23.937  ...             70.4             69.0
# 17                 NaN  ...             70.6             69.1
# 18              23.937  ...             70.6             68.0
# 19                 NaN  ...             70.3             66.7
#
#     rtu_003_sa_temp  rtu_004_sa_temp    mels_S     lig_S    mels_N     hvac_N  \
# 0              68.2             67.4  1.757143  0.100000  8.198750  23.710526
# 1              68.7             67.7       NaN       NaN       NaN        NaN
# 2              68.4             67.6       NaN       NaN       NaN        NaN
# 3              68.1             67.3  1.766667  0.087500  1.881521   8.211429
# 4              68.0             67.4       NaN       NaN       NaN        NaN
# 5              68.0             67.1       NaN       NaN       NaN        NaN
# 6              67.7             68.4  1.900000  0.100000  3.277132   8.283333
# 7              67.8             68.9       NaN       NaN       NaN        NaN
# 8              68.1             67.0       NaN       NaN       NaN        NaN
# 9              67.3             68.3  1.800000  0.000000  1.606442   8.491667
# 10             67.8             68.5       NaN       NaN       NaN        NaN
# 11             67.1             68.0       NaN       NaN       NaN        NaN
# 12             67.8             68.0  1.850000  0.600000  2.527282   8.700000
# 13             67.9             67.7       NaN       NaN       NaN        NaN
# 14             67.5             67.8       NaN       NaN       NaN        NaN
# 15             67.3             67.7  1.235032  0.933543  2.697280   9.863001
# 16             67.5             67.2       NaN       NaN       NaN        NaN
# 17             67.7             67.6       NaN       NaN       NaN        NaN
# 18             67.4             67.4  2.078990  1.532951  3.836045  10.876384
# 19             67.5             67.4       NaN       NaN       NaN        NaN
#
#        hvac_S  Unnamed: 6
# 0   28.021053         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3   24.015000   25.880000
# 4         NaN         NaN
# 5         NaN         NaN
# 6   24.975000   27.115789
# 7         NaN         NaN
# 8         NaN         NaN
# 9   25.700000   25.950000
# 10        NaN         NaN
# 11        NaN         NaN
# 12  25.190909   24.854545
# 13        NaN         NaN
# 14        NaN         NaN
# 15  27.428276   20.866115
# 16        NaN         NaN
# 17        NaN         NaN
# 18  25.019554   17.447124
# 19        NaN         NaN
#
# [20 rows x 93 columns]

# %%
# Verify the data

print(merged_df.columns)
#display(merged_df.head(500))
print("Total rows:", merged_df.shape[0])
print("Total columns:", merged_df.shape[1])
print(merged_df.head())
print("Columns in dataset:", merged_df.columns)
# Check the percentage of missing values in each column

# Count missing values and calculate percentage
missing_data = merged_df.isnull().sum()
missing_percentage = (missing_data / len(merged_df)) * 100

# Combine into a DataFrame
missing_summary = pd.DataFrame({
    "Missing Count": missing_data,
    "Missing Percentage": missing_percentage
})

# Display missing data sorted by percentage
missing_summary = missing_summary.sort_values(by="Missing Percentage", ascending=False)
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
print(missing_summary)

# %%
# Interpolate the missing data, interpolate the gaps with pandas:
merged_df.interpolate(method="linear", inplace=True)
merged_df.fillna(method="ffill", inplace=True)  # Forward Fill
merged_df.fillna(method="bfill", inplace=True)  # Backward Fill
print("Final Missing Values Check:")
print(merged_df.isna().sum().sort_values(ascending=False))
print("Final Shape of Cleaned Dataset:", merged_df.shape)
display(merged_df.head())
# Out:
# Final Missing Values Check:
# Unnamed: 6                   0
# date                         0
# aru_001_power_mbtuph         0
# aru_001_hwr_temp             0
# aru_001_hws_fr_gpm           0
# rtu_003_sf_vfd_spd_fbk_tn    0
# rtu_004_sf_vfd_spd_fbk_tn    0
# rtu_001_rf_vfd_spd_fbk_tn    0
# rtu_002_rf_vfd_spd_fbk_tn    0
# rtu_003_rf_vfd_spd_fbk_tn    0
# rtu_004_rf_vfd_spd_fbk_tn    0
# rtu_001_sa_temp              0
# rtu_002_sa_temp              0
# cerc_templogger_2            0
# cerc_templogger_3            0
# cerc_templogger_4            0
# cerc_templogger_5            0
# cerc_templogger_6            0
# cerc_templogger_7            0
# cerc_templogger_8            0
# cerc_templogger_9            0
# zone_016_temp                0
# zone_017_temp                0
# zone_018_temp                0
# zone_019_temp                0
# zone_021_temp                0
# zone_022_temp                0
# zone_023_temp                0
# zone_024_temp                0
# zone_025_temp                0
# zone_026_temp                0
# zone_027_temp                0
# zone_028_temp                0
# zone_030_temp                0
# zone_032_temp                0
# zone_033_temp                0
# zone_035_temp                0
# zone_036_temp                0
# zone_037_temp                0
# zone_038_temp                0
# zone_039_temp                0
# zone_040_temp                0
# zone_041_temp                0
# zone_042_temp                0
# zone_043_temp                0
# zone_044_temp                0
# zone_045_temp                0
# zone_046_temp                0
# zone_047_temp                0
# zone_048_temp                0
# zone_049_temp                0
# zone_051_temp                0
# zone_052_temp                0
# zone_053_temp                0
# zone_054_temp                0
# zone_055_temp                0
# zone_056_temp                0
# zone_057_temp                0
# zone_058_temp                0
# zone_059_temp                0
# zone_061_temp                0
# zone_062_temp                0
# zone_063_temp                0
# zone_064_temp                0
# zone_065_temp                0
# zone_066_temp                0
# zone_067_temp                0
# zone_068_temp                0
# zone_069_temp                0
# zone_070_temp                0
# zone_071_temp                0
# zone_072_temp                0
# aru_001_cwr_temp             0
# aru_001_cws_fr_gpm           0
# aru_001_cws_temp             0
# rtu_001_sf_vfd_spd_fbk_tn    0
# rtu_002_sf_vfd_spd_fbk_tn    0
# rtu_003_sa_temp              0
# rtu_004_sa_temp              0
# mels_S                       0
# lig_S                        0
# mels_N                       0
# hvac_N                       0
# hvac_S                       0
# aru_001_hws_temp             0
# cerc_templogger_1            0
# cerc_templogger_10           0
# cerc_templogger_11           0
# cerc_templogger_12           0
# cerc_templogger_13           0
# cerc_templogger_14           0
# cerc_templogger_15           0
# cerc_templogger_16           0
# dtype: int64
# Final Shape of Cleaned Dataset: (112368, 93)
# <ipython-input-6-da479b3a5379>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df.fillna(method="ffill", inplace=True)  # Forward Fill
# <ipython-input-6-da479b3a5379>:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df.fillna(method="bfill", inplace=True)  # Backward Fill
#                  date  aru_001_power_mbtuph  aru_001_hwr_temp  \
# 0 2020-01-01 00:00:00              8.614244            121.55
# 1 2020-01-01 00:05:00              8.614244            120.95
# 2 2020-01-01 00:10:00              8.614244            117.23
# 3 2020-01-01 00:15:00              8.614244            120.61
# 4 2020-01-01 00:20:00              8.614244            122.66
#
#    aru_001_hws_fr_gpm  aru_001_hws_temp  cerc_templogger_1  \
# 0               62.36            126.27            22.6870
# 1               62.26            121.87            22.7185
# 2               62.26            121.76            22.7500
# 3               62.25            125.12            22.7500
# 4               62.25            124.05            22.7500
#
#    cerc_templogger_10  cerc_templogger_11  cerc_templogger_12  \
# 0            0.000000             24.0000             23.9370
# 1           12.014907             24.1560             23.9685
# 2           24.029814             24.3120             24.0000
# 3           24.023496             24.3435             23.9375
# 4           24.017178             24.3750             23.8750
#
#    cerc_templogger_13  cerc_templogger_14  cerc_templogger_15  \
# 0             23.9370              23.312              23.250
# 1             24.1245              23.312              23.281
# 2             24.3120              23.312              23.312
# 3             24.0935              23.312              23.312
# 4             23.8750              23.312              23.312
#
#    cerc_templogger_16  cerc_templogger_2  cerc_templogger_3  \
# 0             22.9370             21.687            25.1870
# 1             22.9685             21.687            25.1870
# 2             23.0000             21.687            25.1870
# 3             22.9685             21.656            25.2185
# 4             22.9370             21.625            25.2500
#
#    cerc_templogger_4  cerc_templogger_5  cerc_templogger_6  cerc_templogger_7  \
# 0             23.625            22.9370            22.3750             21.500
# 1             23.656            22.8745            22.4060             21.531
# 2             23.687            22.8120            22.4370             21.562
# 3             23.656            22.9370            22.3745             21.531
# 4             23.625            23.0620            22.3120             21.500
#
#    cerc_templogger_8  cerc_templogger_9  zone_016_temp  zone_017_temp  \
# 0            22.7500            24.0000           74.4           71.1
# 1            22.8435            23.9375           74.4           71.1
# 2            22.9370            23.8750           74.4           71.1
# 3            22.9060            23.9060           74.4           71.1
# 4            22.8750            23.9370           74.4           71.1
#
#    zone_018_temp  zone_019_temp  zone_021_temp  zone_022_temp  zone_023_temp  \
# 0           71.2           73.6           69.1           71.9           70.6
# 1           71.3           73.6           69.2           71.9           70.7
# 2           71.3           73.6           69.2           71.9           70.8
# 3           71.3           73.6           69.2           71.9           70.8
# 4           71.3           73.6           69.2           71.9           70.8
#
#    zone_024_temp  zone_025_temp  zone_026_temp  zone_027_temp  zone_028_temp  \
# 0           72.8           71.3           72.4           72.5           74.3
# 1           72.8           71.3           72.6           72.6           74.3
# 2           72.9           71.4           72.6           72.7           74.3
# 3           72.9           71.4           72.7           73.4           74.6
# 4           72.9           71.5           72.7           73.9           74.8
#
#    zone_030_temp  zone_032_temp  zone_033_temp  zone_035_temp  zone_036_temp  \
# 0           72.0           70.9           70.0           69.5           70.9
# 1           72.0           70.9           70.0           69.5           70.9
# 2           72.0           70.9           69.7           69.5           70.9
# 3           72.0           70.9           70.0           69.6           70.9
# 4           72.0           70.9           70.0           69.6           70.9
#
#    zone_037_temp  zone_038_temp  zone_039_temp  zone_040_temp  zone_041_temp  \
# 0           69.1           72.0           71.2           74.6           74.6
# 1           69.2           72.0           71.2           75.1           74.7
# 2           69.2           72.0           71.0           75.3           74.7
# 3           69.2           72.0           71.0           75.6           74.8
# 4           69.2           72.0           71.0           75.6           74.7
#
#    zone_042_temp  zone_043_temp  zone_044_temp  zone_045_temp  zone_046_temp  \
# 0           74.0           76.6           75.6           71.5           70.5
# 1           74.0           76.6           75.6           71.5           70.5
# 2           74.1           76.7           75.6           71.5           70.5
# 3           74.2           76.7           75.9           71.5           70.5
# 4           74.2           76.6           75.6           71.5           70.5
#
#    zone_047_temp  zone_048_temp  zone_049_temp  zone_051_temp  zone_052_temp  \
# 0           71.0           70.2           72.1           68.6           71.5
# 1           71.0           70.2           72.1           68.6           72.2
# 2           71.0           70.2           72.1           68.6           72.7
# 3           70.9           70.3           72.1           68.6           73.2
# 4           71.0           70.3           72.1           68.6           73.2
#
#    zone_053_temp  zone_054_temp  zone_055_temp  zone_056_temp  zone_057_temp  \
# 0           71.8           70.2           69.6           71.5           72.4
# 1           71.9           70.4           69.7           71.6           72.6
# 2           71.9           70.4           69.7           71.7           73.4
# 3           71.9           70.5           69.8           71.7           73.8
# 4           71.9           70.6           69.8           71.8           74.1
#
#    zone_058_temp  zone_059_temp  zone_061_temp  zone_062_temp  zone_063_temp  \
# 0           74.7           71.8           71.6           71.9           71.3
# 1           74.7           71.8           71.7           71.9           71.3
# 2           75.0           71.8           71.7           71.9           71.3
# 3           75.0           71.8           71.7           71.9           71.3
# 4           75.0           71.8           71.7           71.9           71.3
#
#    zone_064_temp  zone_065_temp  zone_066_temp  zone_067_temp  zone_068_temp  \
# 0           72.0           70.9           71.3           71.6           73.2
# 1           72.0           71.0           71.3           71.6           73.2
# 2           72.0           71.0           71.3           71.5           73.2
# 3           72.1           71.0           71.3           71.5           73.2
# 4           72.1           71.0           71.3           71.5           73.2
#
#    zone_069_temp  zone_070_temp  zone_071_temp  zone_072_temp  \
# 0           72.7           71.6           73.0           73.2
# 1           73.0           71.7           73.5           73.2
# 2           74.0           71.7           73.7           73.2
# 3           74.6           71.8           73.8           73.2
# 4           75.0           71.8           73.9           73.5
#
#    aru_001_cwr_temp  aru_001_cws_fr_gpm  aru_001_cws_temp  \
# 0             63.05                80.2             63.08
# 1             63.05                80.2             63.08
# 2             63.05                80.2             63.08
# 3             63.05                80.2             63.08
# 4             63.05                80.2             63.08
#
#    rtu_001_sf_vfd_spd_fbk_tn  rtu_002_sf_vfd_spd_fbk_tn  \
# 0                       80.1                       81.0
# 1                       80.7                       81.4
# 2                       82.4                       83.7
# 3                       80.2                       81.0
# 4                       83.0                       83.8
#
#    rtu_003_sf_vfd_spd_fbk_tn  rtu_004_sf_vfd_spd_fbk_tn  \
# 0                       80.0                       80.7
# 1                       80.7                       81.4
# 2                       82.7                       82.6
# 3                       79.8                       80.5
# 4                       82.7                       83.1
#
#    rtu_001_rf_vfd_spd_fbk_tn  rtu_002_rf_vfd_spd_fbk_tn  \
# 0                       53.4                       61.7
# 1                       60.8                       67.8
# 2                       58.5                       61.3
# 3                       62.8                       57.4
# 4                       59.0                       64.2
#
#    rtu_003_rf_vfd_spd_fbk_tn  rtu_004_rf_vfd_spd_fbk_tn  rtu_001_sa_temp  \
# 0                       48.5                       82.8             62.5
# 1                       51.6                       91.0             65.2
# 2                       54.6                       91.5             64.6
# 3                       53.8                       89.2             63.1
# 4                       55.2                       93.7             63.3
#
#    rtu_002_sa_temp  rtu_003_sa_temp  rtu_004_sa_temp    mels_S     lig_S  \
# 0             67.7             68.2             67.4  1.757143  0.100000
# 1             67.4             68.7             67.7  1.760317  0.095833
# 2             68.7             68.4             67.6  1.763492  0.091667
# 3             68.3             68.1             67.3  1.766667  0.087500
# 4             67.1             68.0             67.4  1.811111  0.091667
#
#      mels_N     hvac_N     hvac_S  Unnamed: 6
# 0  8.198750  23.710526  28.021053    25.88000
# 1  6.093007  18.544160  26.685702    25.88000
# 2  3.987264  13.377794  25.350351    25.88000
# 3  1.881521   8.211429  24.015000    25.88000
# 4  2.346725   8.235397  24.335000    26.29193

# %%
# Normalize the data
# Identify numerical columns (excluding 'date')
numeric_cols = merged_df.select_dtypes(include=["float64", "int64"]).columns.tolist()
print("🔍 Numerical Columns for Normalization:", numeric_cols)

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Apply MinMax Scaling ONLY to numerical columns
merged_df[numeric_cols] = scaler.fit_transform(merged_df[numeric_cols])

# Check to ensure all values are normalized
for col in numeric_cols:
    min_val, max_val = merged_df[col].min(), merged_df[col].max()
    if min_val < 0 or max_val > 1:
        print(f"Warning: Column '{col}' has values outside [0, 1]. Min: {min_val}, Max: {max_val}")
    else:
        print(f"Column '{col}' is correctly normalized. Min: {min_val}, Max: {max_val}")

print("Normalization complete!")
display(merged_df.head())
# Out:
# 🔍 Numerical Columns for Normalization: ['aru_001_power_mbtuph', 'aru_001_hwr_temp', 'aru_001_hws_fr_gpm', 'aru_001_hws_temp', 'cerc_templogger_1', 'cerc_templogger_10', 'cerc_templogger_11', 'cerc_templogger_12', 'cerc_templogger_13', 'cerc_templogger_14', 'cerc_templogger_15', 'cerc_templogger_16', 'cerc_templogger_2', 'cerc_templogger_3', 'cerc_templogger_4', 'cerc_templogger_5', 'cerc_templogger_6', 'cerc_templogger_7', 'cerc_templogger_8', 'cerc_templogger_9', 'zone_016_temp', 'zone_017_temp', 'zone_018_temp', 'zone_019_temp', 'zone_021_temp', 'zone_022_temp', 'zone_023_temp', 'zone_024_temp', 'zone_025_temp', 'zone_026_temp', 'zone_027_temp', 'zone_028_temp', 'zone_030_temp', 'zone_032_temp', 'zone_033_temp', 'zone_035_temp', 'zone_036_temp', 'zone_037_temp', 'zone_038_temp', 'zone_039_temp', 'zone_040_temp', 'zone_041_temp', 'zone_042_temp', 'zone_043_temp', 'zone_044_temp', 'zone_045_temp', 'zone_046_temp', 'zone_047_temp', 'zone_048_temp', 'zone_049_temp', 'zone_051_temp', 'zone_052_temp', 'zone_053_temp', 'zone_054_temp', 'zone_055_temp', 'zone_056_temp', 'zone_057_temp', 'zone_058_temp', 'zone_059_temp', 'zone_061_temp', 'zone_062_temp', 'zone_063_temp', 'zone_064_temp', 'zone_065_temp', 'zone_066_temp', 'zone_067_temp', 'zone_068_temp', 'zone_069_temp', 'zone_070_temp', 'zone_071_temp', 'zone_072_temp', 'aru_001_cwr_temp', 'aru_001_cws_fr_gpm', 'aru_001_cws_temp', 'rtu_001_sf_vfd_spd_fbk_tn', 'rtu_002_sf_vfd_spd_fbk_tn', 'rtu_003_sf_vfd_spd_fbk_tn', 'rtu_004_sf_vfd_spd_fbk_tn', 'rtu_001_rf_vfd_spd_fbk_tn', 'rtu_002_rf_vfd_spd_fbk_tn', 'rtu_003_rf_vfd_spd_fbk_tn', 'rtu_004_rf_vfd_spd_fbk_tn', 'rtu_001_sa_temp', 'rtu_002_sa_temp', 'rtu_003_sa_temp', 'rtu_004_sa_temp', 'mels_S', 'lig_S', 'mels_N', 'hvac_N', 'hvac_S', 'Unnamed: 6']
# Column 'aru_001_power_mbtuph' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'aru_001_hwr_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'aru_001_hws_fr_gpm' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000002
# Column 'aru_001_hws_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_1' is correctly normalized. Min: 0.0, Max: 0.9999999999999999
# Column 'cerc_templogger_10' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'cerc_templogger_11' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000002
# Column 'cerc_templogger_12' is correctly normalized. Min: 0.0, Max: 0.9999999999999998
# Column 'cerc_templogger_13' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_14' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_15' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_16' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_2' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_3' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_4' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_5' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_6' is correctly normalized. Min: 0.0, Max: 0.9999999999999999
# Column 'cerc_templogger_7' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_8' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'cerc_templogger_9' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_016_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_017_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_018_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_019_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_021_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_022_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_023_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_024_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_025_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_026_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_027_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_028_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_030_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_032_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_033_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_035_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999991
# Column 'zone_036_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_037_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_038_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_039_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_040_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_041_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_042_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_043_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_044_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_045_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_046_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_047_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_048_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_049_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_051_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_052_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_053_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_054_temp' is correctly normalized. Min: 0.0, Max: 0.9999999999999996
# Column 'zone_055_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_056_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_057_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_058_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_059_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000009
# Column 'zone_061_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_062_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_063_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_064_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_065_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_066_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_067_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'zone_068_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000004
# Column 'zone_069_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_070_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_071_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'zone_072_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'aru_001_cwr_temp' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000002
# Column 'aru_001_cws_fr_gpm' is correctly normalized. Min: 0.0, Max: 0.9999999999999999
# Column 'aru_001_cws_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_001_sf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_002_sf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_003_sf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_004_sf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Warning: Column 'rtu_001_rf_vfd_spd_fbk_tn' has values outside [0, 1]. Min: 0.0, Max: 1.0000000000000002
# Column 'rtu_002_rf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_003_rf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_004_rf_vfd_spd_fbk_tn' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_001_sa_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_002_sa_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_003_sa_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'rtu_004_sa_temp' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'mels_S' is correctly normalized. Min: 0.0, Max: 0.9999999999999999
# Column 'lig_S' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'mels_N' is correctly normalized. Min: 0.0, Max: 0.9999999999999999
# Column 'hvac_N' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'hvac_S' is correctly normalized. Min: 0.0, Max: 1.0
# Column 'Unnamed: 6' is correctly normalized. Min: 0.0, Max: 1.0
# Normalization complete!
#                  date  aru_001_power_mbtuph  aru_001_hwr_temp  \
# 0 2020-01-01 00:00:00               0.02026          0.927623
# 1 2020-01-01 00:05:00               0.02026          0.921541
# 2 2020-01-01 00:10:00               0.02026          0.883832
# 3 2020-01-01 00:15:00               0.02026          0.918094
# 4 2020-01-01 00:20:00               0.02026          0.938875
#
#    aru_001_hws_fr_gpm  aru_001_hws_temp  cerc_templogger_1  \
# 0            0.916622          0.957464           0.045933
# 1            0.915149          0.914139           0.046415
# 2            0.915149          0.913056           0.046897
# 3            0.915001          0.946140           0.046897
# 4            0.915001          0.935605           0.046897
#
#    cerc_templogger_10  cerc_templogger_11  cerc_templogger_12  \
# 0            0.000000            0.503252            0.489130
# 1            0.432004            0.519356            0.491870
# 2            0.864009            0.535460            0.494609
# 3            0.863782            0.538712            0.489174
# 4            0.863555            0.541963            0.483739
#
#    cerc_templogger_13  cerc_templogger_14  cerc_templogger_15  \
# 0            0.604774            0.554712            0.857143
# 1            0.628968            0.554712            0.858286
# 2            0.653161            0.554712            0.859429
# 3            0.624968            0.554712            0.859429
# 4            0.596774            0.554712            0.859429
#
#    cerc_templogger_16  cerc_templogger_2  cerc_templogger_3  \
# 0            0.074557           0.423518           0.296318
# 1            0.075026           0.423518           0.296318
# 2            0.075496           0.423518           0.296318
# 3            0.075026           0.419827           0.296688
# 4            0.074557           0.416137           0.297059
#
#    cerc_templogger_4  cerc_templogger_5  cerc_templogger_6  cerc_templogger_7  \
# 0           0.614667           0.055185           0.111124           0.340761
# 1           0.619833           0.054234           0.112028           0.344435
# 2           0.625000           0.053282           0.112931           0.348110
# 3           0.619833           0.055185           0.111109           0.344435
# 4           0.614667           0.057088           0.109288           0.340761
#
#    cerc_templogger_8  cerc_templogger_9  zone_016_temp  zone_017_temp  \
# 0           0.630277           0.585714       0.765714       0.513661
# 1           0.642848           0.578571       0.765714       0.513661
# 2           0.655418           0.571429       0.765714       0.513661
# 3           0.651250           0.574971       0.765714       0.513661
# 4           0.647083           0.578514       0.765714       0.513661
#
#    zone_018_temp  zone_019_temp  zone_021_temp  zone_022_temp  zone_023_temp  \
# 0        0.55414       0.166078       0.510638          0.625       0.517179
# 1        0.56051       0.166078       0.515957          0.625       0.521881
# 2        0.56051       0.166078       0.515957          0.625       0.526582
# 3        0.56051       0.166078       0.515957          0.625       0.526582
# 4        0.56051       0.166078       0.515957          0.625       0.526582
#
#    zone_024_temp  zone_025_temp  zone_026_temp  zone_027_temp  zone_028_temp  \
# 0       0.651515       0.555556       0.521053       0.465241       0.543860
# 1       0.651515       0.555556       0.531579       0.470588       0.543860
# 2       0.656566       0.561728       0.531579       0.475936       0.543860
# 3       0.656566       0.561728       0.536842       0.513369       0.557018
# 4       0.656566       0.567901       0.536842       0.540107       0.565789
#
#    zone_030_temp  zone_032_temp  zone_033_temp  zone_035_temp  zone_036_temp  \
# 0           0.54       0.526786       0.492063       0.416058       0.406015
# 1           0.54       0.526786       0.492063       0.416058       0.406015
# 2           0.54       0.526786       0.468254       0.416058       0.406015
# 3           0.54       0.526786       0.492063       0.423358       0.406015
# 4           0.54       0.526786       0.492063       0.423358       0.406015
#
#    zone_037_temp  zone_038_temp  zone_039_temp  zone_040_temp  zone_041_temp  \
# 0       0.321839        0.48538       0.391837       0.614286       0.606635
# 1       0.327586        0.48538       0.391837       0.638095       0.611374
# 2       0.327586        0.48538       0.383673       0.647619       0.611374
# 3       0.327586        0.48538       0.383673       0.661905       0.616114
# 4       0.327586        0.48538       0.383673       0.661905       0.611374
#
#    zone_042_temp  zone_043_temp  zone_044_temp  zone_045_temp  zone_046_temp  \
# 0       0.456731       0.724324       0.607143       0.437037       0.564103
# 1       0.456731       0.724324       0.607143       0.437037       0.564103
# 2       0.461538       0.729730       0.607143       0.437037       0.564103
# 3       0.466346       0.729730       0.622449       0.437037       0.564103
# 4       0.466346       0.724324       0.607143       0.437037       0.564103
#
#    zone_047_temp  zone_048_temp  zone_049_temp  zone_051_temp  zone_052_temp  \
# 0       0.518919       0.488889       0.330189       0.488506       0.708122
# 1       0.518919       0.488889       0.330189       0.488506       0.725888
# 2       0.518919       0.488889       0.330189       0.488506       0.738579
# 3       0.513514       0.496296       0.330189       0.488506       0.751269
# 4       0.518919       0.496296       0.330189       0.488506       0.751269
#
#    zone_053_temp  zone_054_temp  zone_055_temp  zone_056_temp  zone_057_temp  \
# 0       0.522388       0.497207       0.431034       0.472222       0.469274
# 1       0.527363       0.508380       0.436782       0.477778       0.480447
# 2       0.527363       0.508380       0.436782       0.483333       0.525140
# 3       0.527363       0.513966       0.442529       0.483333       0.547486
# 4       0.527363       0.519553       0.442529       0.488889       0.564246
#
#    zone_058_temp  zone_059_temp  zone_061_temp  zone_062_temp  zone_063_temp  \
# 0       0.546798       0.516129       0.450382       0.368421       0.483146
# 1       0.546798       0.516129       0.458015       0.368421       0.483146
# 2       0.561576       0.516129       0.458015       0.368421       0.483146
# 3       0.561576       0.516129       0.458015       0.368421       0.483146
# 4       0.561576       0.516129       0.458015       0.368421       0.483146
#
#    zone_064_temp  zone_065_temp  zone_066_temp  zone_067_temp  zone_068_temp  \
# 0       0.478632       0.413580       0.474453       0.507576       0.508108
# 1       0.478632       0.419753       0.474453       0.507576       0.508108
# 2       0.478632       0.419753       0.474453       0.500000       0.508108
# 3       0.487179       0.419753       0.474453       0.500000       0.508108
# 4       0.487179       0.419753       0.474453       0.500000       0.508108
#
#    zone_069_temp  zone_070_temp  zone_071_temp  zone_072_temp  \
# 0       0.426230       0.477707       0.412121       0.564516
# 1       0.442623       0.484076       0.442424       0.564516
# 2       0.497268       0.484076       0.454545       0.564516
# 3       0.530055       0.490446       0.460606       0.564516
# 4       0.551913       0.490446       0.466667       0.588710
#
#    aru_001_cwr_temp  aru_001_cws_fr_gpm  aru_001_cws_temp  \
# 0          0.665329            0.422027          0.557672
# 1          0.665329            0.422027          0.557672
# 2          0.665329            0.422027          0.557672
# 3          0.665329            0.422027          0.557672
# 4          0.665329            0.422027          0.557672
#
#    rtu_001_sf_vfd_spd_fbk_tn  rtu_002_sf_vfd_spd_fbk_tn  \
# 0                     0.8408                     0.8480
# 1                     0.8456                     0.8512
# 2                     0.8592                     0.8696
# 3                     0.8416                     0.8480
# 4                     0.8640                     0.8704
#
#    rtu_003_sf_vfd_spd_fbk_tn  rtu_004_sf_vfd_spd_fbk_tn  \
# 0                     0.8400                     0.8456
# 1                     0.8456                     0.8512
# 2                     0.8616                     0.8608
# 3                     0.8384                     0.8440
# 4                     0.8616                     0.8648
#
#    rtu_001_rf_vfd_spd_fbk_tn  rtu_002_rf_vfd_spd_fbk_tn  \
# 0                   0.637917                   0.744206
# 1                   0.698129                   0.796567
# 2                   0.679414                   0.740773
# 3                   0.714402                   0.707296
# 4                   0.683483                   0.765665
#
#    rtu_003_rf_vfd_spd_fbk_tn  rtu_004_rf_vfd_spd_fbk_tn  rtu_001_sa_temp  \
# 0                   0.692743                     0.8624         0.681570
# 1                   0.721960                     0.9280         0.711014
# 2                   0.750236                     0.9320         0.704471
# 3                   0.742696                     0.9136         0.688113
# 4                   0.755891                     0.9496         0.690294
#
#    rtu_002_sa_temp  rtu_003_sa_temp  rtu_004_sa_temp    mels_S     lig_S  \
# 0         0.685223         0.748628         0.785548  0.150193  0.013905
# 1         0.682186         0.754116         0.789044  0.150421  0.013517
# 2         0.695344         0.750823         0.787879  0.150649  0.013130
# 3         0.691296         0.747530         0.784382  0.150876  0.012743
# 4         0.679150         0.746432         0.785548  0.154066  0.013130
#
#      mels_N    hvac_N    hvac_S  Unnamed: 6
# 0  0.804597  0.720685  0.392732    0.399310
# 1  0.608455  0.563652  0.374016    0.399310
# 2  0.412313  0.406620  0.355301    0.399310
# 3  0.216171  0.249587  0.336585    0.399310
# 4  0.259503  0.250316  0.341070    0.405665

# %%
# Save the cleaned data to drive
# Define the shared Google Drive folder path
SAVE_PATH = "/content/drive/MyDrive/connect_clean_data/"

# Save as CSV (For manual checking)
merged_df.to_csv(f"{SAVE_PATH}processed_data.csv", index=False)

# Save as Pickle (For fast AI model training)
merged_df.to_pickle(f"{SAVE_PATH}processed_data.pkl")

# Save as JSON (For the app)
json_data = merged_df.to_dict(orient="records")  # Convert DataFrame to JSON format
with open(f"{SAVE_PATH}processed_data.json", "w") as json_file:
    json.dump(json_data, json_file, indent=4)

print("Preprocessed dataset saved in CSV, Pickle & JSON formats in 'connect_clean_data'!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-2af654bbde5d> in <cell line: 0>()
#       4
#       5 # Save as CSV (For manual checking)
# ----> 6 merged_df.to_csv(f"{SAVE_PATH}processed_data.csv", index=False)
#       7
#       8 # Save as Pickle (For fast AI model training)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: '/content/drive/MyDrive/connect_clean_data'

# %%
# Do Statistical analysis on trends and peak times before AI forecasting

# Define different energy categories
y_hvac = (merged_df["hvac_N"] + merged_df["hvac_S"]) / 2  # HVAC Energy (Averaged)
y_lighting = merged_df["lig_S"]  # Lighting Energy (Single Source)
y_mels = (merged_df["mels_N"] + merged_df["mels_S"]) / 2  # Miscellaneous Load (Averaged)

# Add them back to the dataset
merged_df["total_hvac"] = y_hvac
merged_df["total_lighting"] = y_lighting
merged_df["total_mels"] = y_mels
merged_df["hour"] = merged_df["date"].dt.hour

# HVAC Energy Usage by Hour
hvac_hourly = merged_df.groupby("hour")["total_hvac"].mean()
plt.figure(figsize=(10, 5))
hvac_hourly.plot(kind="bar", title="HVAC Energy Usage by Hour")
plt.ylabel("Energy Usage")
plt.xlabel("Hour of Day")
plt.show()

# Lighting Energy Usage by Hour
lighting_hourly = merged_df.groupby("hour")["total_lighting"].mean()
plt.figure(figsize=(10, 5))
lighting_hourly.plot(kind="bar", title="Lighting Energy Usage by Hour")
plt.ylabel("Energy Usage")
plt.xlabel("Hour of Day")
plt.show()

# MELS Energy Usage by Hour
mels_hourly = merged_df.groupby("hour")["total_mels"].mean()
plt.figure(figsize=(10, 5))
mels_hourly.plot(kind="bar", title="MELS Energy Usage by Hour")
plt.ylabel("Energy Usage")
plt.xlabel("Hour of Day")
plt.show()

# Extract day of the week and compute averages and trends
merged_df["day_of_week"] = merged_df["date"].dt.dayofweek

# Compute weekly average
weekly_usage = merged_df.groupby("day_of_week")[["total_hvac", "total_lighting", "total_mels"]].mean()

# Plot weekly trends
weekly_usage.plot(kind="bar", figsize=(12, 5), title="Energy Usage by Day of the Week")
plt.xticks(ticks=range(7), labels=["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"], rotation=0)
plt.show()

# Correlation between temperature & HVAC, lighting and miscilanious energy usage
energy_metrics = ["total_hvac", "total_lighting", "total_mels"]
temp_cols = [col for col in merged_df.columns if "temp" in col]
corr_matrix = merged_df[temp_cols + energy_metrics].corr()

threshold = 0.3 # threshold correlation
filtered_corr = corr_matrix.loc[energy_metrics, temp_cols]
significant_temp_cols = filtered_corr.columns[(filtered_corr.abs() > threshold).any()]
filtered_corr = filtered_corr[significant_temp_cols]

plt.figure(figsize=(25, 5))
sns.heatmap(filtered_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation: Temperature vs. Energy Metrics")
plt.xlabel("Temperature Columns")
plt.ylabel("Energy Metrics")
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Compute correlation matrix
correlation_matrix = merged_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation Matrix")
plt.show()

# Compute monthly and weekday vs. weekend trends
merged_df["month"] = merged_df["date"].dt.month
monthly_usage = merged_df.groupby("month")[["total_hvac", "total_lighting", "total_mels"]].mean()

monthly_usage.plot(kind="bar", figsize=(12, 5), title="Energy Usage by Month")
plt.xticks(ticks=range(1, 13), labels=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], rotation=0)
plt.show()

merged_df["is_weekend"] = merged_df["day_of_week"].apply(lambda x: 1 if x >= 5 else 0)
weekend_usage = merged_df.groupby("is_weekend")[["total_hvac", "total_lighting", "total_mels"]].mean()

weekend_usage.plot(kind="bar", figsize=(8, 5), title="Energy Usage: Weekday vs. Weekend", legend=True)
plt.xticks(ticks=[0, 1], labels=["Weekday", "Weekend"], rotation=0)
plt.show()

# Compute boxplots for outlier detection
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df[["total_hvac", "total_lighting", "total_mels"]])
plt.title("Outlier Detection in Energy Usage")
plt.show()

# %%
# Do analysis on the varibility of the data for insights on the utility of AI
merged_df["date"] = pd.to_datetime(merged_df["date"])

# Extract time components
merged_df["hour"] = merged_df["date"].dt.hour
merged_df["day"] = merged_df["date"].dt.date
merged_df["day_of_week"] = merged_df["date"].dt.dayofweek
merged_df["month"] = merged_df["date"].dt.month

# Define energy-related columns
energy_cols = ["total_hvac", "total_lighting", "total_mels"]
energy_scaled = merged_df[energy_cols].values

print("Min and Max values of normalized energy_scaled:")
print("Min:", energy_scaled.min())
print("Max:", energy_scaled.max())

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
merged_df["usage_cluster"] = kmeans.fit_predict(energy_scaled)

# Visualize the clusters
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=merged_df,
    x="date",
    y="total_hvac",
    hue="usage_cluster",
    palette="coolwarm",
    alpha=0.7
)
plt.title("Clusters of HVAC Energy Usage Patterns Over Time")
plt.xlabel("Date")
plt.ylabel("Total HVAC Energy (Normalized)")
plt.legend(title="Usage Cluster", loc="upper right")
plt.grid(True)
plt.show()


# Plot the daily variability
daily_variability = merged_df.groupby(merged_df["date"].dt.date)[["total_hvac", "total_lighting", "total_mels", "zone_016_temp"]].std()
plt.figure(figsize=(12, 5))
daily_variability.plot(title="Daily Variability of Energy Usage & Temperature")
plt.ylabel("Standard Deviation")
plt.show()

# Visualize the top 10 collumns with the highest varibility
top_columns = daily_variability.std().nlargest(10).index
daily_variability[top_columns].plot(title="Daily Variability: Top 10 Columns", figsize=(12, 6))
plt.show()

# Compute difference in temperature over time and correlation with total hvac and print
merged_df["temp_change"] = merged_df["zone_016_temp"].diff()

hvac_temp_corr = merged_df[["temp_change", "total_hvac"]].corr()
print("Correlation between HVAC Usage & Temperature Change:")
print(hvac_temp_corr)

# Plot the variability for the energy categories
temp_cols = [col for col in merged_df.columns if "temp" in col.lower()]
fan_speed_cols = [col for col in merged_df.columns if "fan_spd" in col.lower()]
water_temp_cols = [col for col in merged_df.columns if "hws_temp" in col.lower() or "cws_temp" in col.lower()]

daily_variability = merged_df.groupby("day")[energy_cols + temp_cols + fan_speed_cols + water_temp_cols].std()

plt.figure(figsize=(12, 5))
daily_variability[energy_cols].plot(title="Daily Energy Usage Variability")
plt.show()

# Filter specific categories for separate plots
zone_temps = [col for col in daily_variability.columns if "zone_" in col]
rtu_temps = [col for col in daily_variability.columns if "rtu_" in col]

zone_temp_cols = [col for col in daily_variability.columns if "zone_" in col]

zone_temp_variability = daily_variability[zone_temp_cols].std()

top_10_zone_temps = zone_temp_variability.nlargest(10).index

# Plot the top 10 zone temperature columns
daily_variability[top_10_zone_temps].plot(title="Daily Variability: Top 10 Zone Temperatures", figsize=(12, 6))
plt.ylabel("Standard Deviation")
plt.xlabel("Date")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)  # Move legend outside
plt.tight_layout()
plt.show()

# Plot the variability of the water temperature
plt.figure(figsize=(12, 5))
daily_variability[water_temp_cols].plot(title="Daily Hot/Cold Water Temperature Variability")
plt.show()
